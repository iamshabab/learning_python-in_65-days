# %% [markdown]
# Week 1 Review Project — Student Grade Management System
# This project combines everything from Days 1–7: variables, data types, strings, lists, tuples, dictionaries, sets, conditionals, and loops. No new concepts — just applying what you already know.

# %% [markdown]
# # 1. Print a welcome banner using print() and comments to label each section
# # 2. Create variables: class_name (str), num_students (int), pass_mark (float)
# #    e.g. class_name = "Python 101", num_students = 5, pass_mark = 60.0
# # 3. Print a sentence using an f-string that includes all 3 variables

# %%
print("wellcome")       #basic output

class_name = "python 101"
num_student = 5
pass_marks = 60.0

print(f"class name:{class_name}    number of students:{num_student}       passing marks:{pass_marks}")
# Out:
# wellcome
# class name:python 101    number of students:5       passing marks:60.0

# %% [markdown]
# # 4. Create a list called "students" containing 5 nested lists, each with:
# #    [name, score]
# #    e.g. ["Ahmed", 78]
#
# # 5. Create a dictionary called "class_info" with keys:
# #    "class_name", "teacher", "subject" — fill with your own values
#
# # 6. Create a tuple called "top_scorer_template" with placeholder values:
# #    ("", 0)  -> you'll fill this in later in the program

# %%
students=[
    ["shabab alam",80],
    ["m jalil",82],
    ["kashif",86],
    ["abdull",90],
    ["john",56],
]
class_info={
    "class_name":"python 101",
    "teacher":"dr wajid khan",
    "subject":"introduction to python",
}
top_score_template=("",0)

# %% [markdown]
# # 7. For each student name in your list, print it in Title Case
# #    even if you typed it in lowercase originally
# # 8. Create one combined string of all student names separated by commas
# #    using .join()

# %%
all_names=[]
for student in students:
    all_names.append(student[0].title())

joined= ", ".join(all_names)
print(joined)
# Out:
# Shabab Alam, M Jalil, Kashif, Abdull, John

# %% [markdown]
# # 9. Loop through the students list and for each student:
# #    - Print their name and score
# #    - Print "PASS" if score >= pass_mark, else "FAIL"
# #
# # 10. While looping, track:
# #     - total_score (sum of all scores)
# #     - highest_score and the name of that student
# #     - count of students who passed
# #     - count of students who failed
# #
# # 11. After the loop, calculate and print:
# #     - class average (total_score / num_students)
# #     - pass percentage
# #     - the top scorer's name and score (update top_scorer_template tuple)

# %%
for student in students:
    print(student)
    score=student[1]
    if score >= pass_marks: print(" pass ")
    else:   print(" fail")
total_score=0
total_students=0
while total_students<6:
    total_students+=1
    total_score+=score
    print(score)

print(f"total score = {total_score}")
# Out:
# ['shabab alam', 80]
#  pass
# ['m jalil', 82]
#  pass
# ['kashif', 86]
#  pass
# ['abdull', 90]
#  pass
# ['john', 56]
#  fail
# 56
# 56
# 56
# 56
# 56
# 56
# total score = 336
